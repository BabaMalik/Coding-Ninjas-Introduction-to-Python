# %% [markdown]
# ### Operations on sets: Union, Intersection and difference

# %%
a = {1,2,3,4}
b = {2,3,4,5,6}

# %%
a.intersection(b)
# Out:
# {2, 3, 4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
b.union(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a.difference(b)
# Out:
# {1}

# %%
b.difference(a)
# Out:
# {5, 6}

# %%
a.symmetric_difference(b)   # Union - Intersection
# Out:
# {1, 5, 6}

# %%
a.intersection_update(b)

# %%
a
# Out:
# {2, 3, 4}

# %%
a.difference_update(b)

# %%
a
# Out:
# {1}

# %%
a.symmetric_difference_update(b)

# %%
a
# Out:
# {1, 5, 6}

# %%
a.union_update(b)     # No union update
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-802d49f7af68> in <module>
# ----> 1 a.union_update(b)     # No union update
#
# AttributeError: 'set' object has no attribute 'union_update'

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
b
# Out:
# {2, 3, 4, 5, 6}

# %%
a.issubset(b)
# Out:
# False

# %%
c = {3,4}

# %%
a.issubset(c)
# Out:
# False

# %%
c.issubset(a)
# Out:
# True

# %%
a.issuperset(c)
# Out:
# True

# %%
a.isdisjoint(b)
# Out:
# False

# %%
d = {434,23}

# %%
a.isdisjoint(d)
# Out:
# True
