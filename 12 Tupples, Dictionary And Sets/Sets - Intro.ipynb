# %% [markdown]
# ##### Sets are unique collection of data but there is no particular order of data

# %%
a = {"apple", "banana", "abc" }     #Just keys not the values
a
# Out:
# {'abc', 'apple', 'banana'}

# %%
type(a)
# Out:
# set

# %%
dict = {"abc": 3, "str" : "Helllo"}    # Has key and value
type(dict)
# Out:
# dict

# %%
a = (1,2,3)
type(a)
# Out:
# tuple

# %%
a = [1,2,3,4]
type(a)
# Out:
# list

# %%
a = {"apple", "banana", "abc" }     #Just keys not the values
a
# Out:
# {'abc', 'apple', 'banana'}

# %%
type(a)
# Out:
# set

# %%
a
# Out:
# {'abc', 'apple', 'banana'}

# %%
'abc' in a    # To check your set contains a value or not
# Out:
# True

# %%
21 in a
# Out:
# False

# %%
for v in a:
    print(v)
# Out:
# abc
# apple
# banana

# %%
len(a)
# Out:
# 3

# %%
a.add("temp")

# %%
a
# Out:
# {'abc', 'apple', 'banana', 'temp'}

# %%
b = {"abc", 'Hello'}

# %%
a.update(b)

# %%
a
# Out:
# {'Hello', 'abc', 'apple', 'banana', 'temp'}

# %%
num = {1,3,2,4,5,4,2}

# %%
num
# Out:
# {1, 2, 3, 4, 5}

# %%
a.remove('temp')

# %%
a
# Out:
# {'Hello', 'abc', 'apple', 'banana'}

# %%
a.remove('Hell')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1ccb2acf5a07> in <module>
# ----> 1 a.remove('Hell')
#
# KeyError: 'Hell'

# %%
a
# Out:
# {'Hello', 'abc', 'apple', 'banana'}

# %%
a.discard(23)

# %%
print(a.discard(23))
# Out:
# None

# %%
a.pop()
# Out:
# 'abc'

# %%
a
# Out:
# {'Hello', 'apple', 'banana'}

# %%
a.pop()
# Out:
# 'banana'

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined
