# %%
s =set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
s = {1,2,1,3,3,2,4,4,4,5}
sum = 0
for i in s:
    sum += i
print(len(s))
print(sum)
# Out:
# 5
# 15

# %%
dic = {}
type(dic)
# Out:
# dict

# %%
def sumUnique(l):
    s = set()
    for i in l:
        s.add(i)
    sum = 0
    for i in s:
        sum = sum + i
    return sum

# %%
sumUnique([1,2,3,2,1,3,4,2,3,1,5,4,5,4,3,5,5,5])
# Out:
# 15
